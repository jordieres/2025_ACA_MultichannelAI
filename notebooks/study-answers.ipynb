# %%
import pandas as pd
import spacy
from spacy.cli import download
from bertopic import BERTopic
from keybert import KeyBERT
from umap import UMAP

from multimodal_fin.analysis_qa_effects import (
    PipelineConfig,
    MultiCompanyRunner,
    CompanyPipeline,
    PopulationEvidenceAnalyzer,
    AggregatedEffectPlotter,
    AnswerPlotter,
    TopicModeler,
    KeywordExtractor,
    TopicLabeler,
    EmotionFeatureBuilder,
    StatsTester,
    TranscriptQALoader,
    TextPreprocessor,
    EmotionAggregator
)

# %%
cfg = PipelineConfig(processed_root="/home/aacastro/mchai/processed_companies")

try:
    nlp = spacy.load("en_core_web_sm")
except OSError:
    download("en_core_web_sm")
    nlp = spacy.load("en_core_web_sm")

topic_model = BERTopic(language="english", min_topic_size=3, embedding_model="multi-qa-distilbert-cos-v1", verbose=False, umap_model=UMAP(random_state=42))
qa_kw_model = KeyBERT(model="all-MiniLM-L12-v2")
topic_kw_model = KeyBERT()

# %%
emo_agg = EmotionAggregator()
loader = TranscriptQALoader(cfg, emo_agg)
preproc = TextPreprocessor(nlp)
topic_modeler = TopicModeler(preproc, topic_model)
kw_extractor = KeywordExtractor(qa_kw_model)
topic_labeler = TopicLabeler(topic_kw_model)
feature_builder = EmotionFeatureBuilder(cfg)
stats = StatsTester(cfg)
plotter = AnswerPlotter()

# %%
pipeline = CompanyPipeline(
    config=cfg,
    loader=loader,
    topic_modeler=topic_modeler,
    kw_extractor=kw_extractor,
    topic_labeler=topic_labeler,
    feature_builder=feature_builder,
    stats=stats,
    plotter=plotter,
)

# %%
data = pd.read_csv("../data/full_paths.csv")
companies = data["company"].unique().tolist()

runner = MultiCompanyRunner(pipeline, cfg, use_tqdm=False)
df_all = runner.run(companies, plot_company="AAPL")
# Out:
# Loaded 181 QA pairs from 13 conferences for company KMI.
# Loaded 248 QA pairs from 20 conferences for company AAPL.
# Loaded 204 QA pairs from 13 conferences for company ABNB.
# Loaded 178 QA pairs from 15 conferences for company WMB.
# Loaded 293 QA pairs from 17 conferences for company PSX.
# Loaded 421 QA pairs from 22 conferences for company TDG.
# Loaded 127 QA pairs from 9 conferences for company APD.
# Loaded 116 QA pairs from 15 conferences for company AWK.
# Loaded 179 QA pairs from 21 conferences for company AMZN.
# Loaded 263 QA pairs from 13 conferences for company ECL.
# Loaded 482 QA pairs from 21 conferences for company SYK.
# Loaded 259 QA pairs from 21 conferences for company MCD.
# Loaded 225 QA pairs from 22 conferences for company CMCSA.
# Loaded 246 QA pairs from 21 conferences for company DHR.
# Loaded 215 QA pairs from 11 conferences for company CHD.
# Loaded 115 QA pairs from 9 conferences for company MDT.
# Loaded 223 QA pairs from 15 conferences for company WEC.
# Loaded 208 QA pairs from 19 conferences for company ACN.
# Loaded 350 QA pairs from 23 conferences for company PFE.
# Loaded 342 QA pairs from 24 conferences for company AMAT.
# Loaded 244 QA pairs from 17 conferences for company CSX.
# Loaded 100 QA pairs from 7 conferences for company CSCO.
# Loaded 191 QA pairs from 17 conferences for company KKR.
# Loaded 280 QA pairs from 23 conferences for company MA.
# Loaded 312 QA pairs from 17 conferences for company PPG.
# Loaded 180 QA pairs from 15 conferences for company NEM.
# Loaded 207 QA pairs from 15 conferences for company RCL.
# Loaded 135 QA pairs from 9 conferences for company OKE.
# Loaded 290 QA pairs from 22 conferences for company MMC.
# Loaded 277 QA pairs from 14 conferences for company JPM.
# Loaded 214 QA pairs from 15 conferences for company ITW.
# Loaded 335 QA pairs from 21 conferences for company CMG.
# Loaded 480 QA pairs from 22 conferences for company WM.
# Loaded 164 QA pairs from 17 conferences for company MTCH.
# Loaded 216 QA pairs from 15 conferences for company SO.
# Loaded 218 QA pairs from 20 conferences for company V.
# Loaded 47 QA pairs from 7 conferences for company CEG.
# Loaded 215 QA pairs from 13 conferences for company WY.
# Loaded 305 QA pairs from 16 conferences for company FANG.
# Loaded 425 QA pairs from 16 conferences for company ROST.
# Loaded 189 QA pairs from 15 conferences for company WELL.
# Loaded 71 QA pairs from 5 conferences for company NFLX.
# Loaded 214 QA pairs from 16 conferences for company AMGN.
# Loaded 442 QA pairs from 18 conferences for company SHW.
# Loaded 187 QA pairs from 16 conferences for company FI.
# Loaded 155 QA pairs from 13 conferences for company KHC.
# Loaded 223 QA pairs from 14 conferences for company VTR.
# Loaded 181 QA pairs from 19 conferences for company KDP.
# Loaded 190 QA pairs from 23 conferences for company IBM.
# Loaded 259 QA pairs from 22 conferences for company BKNG.
# Loaded 102 QA pairs from 10 conferences for company WBD.
# Loaded 60 QA pairs from 6 conferences for company KVUE.
# Loaded 420 QA pairs from 17 conferences for company DHI.
# Loaded 228 QA pairs from 19 conferences for company BKR.
# Loaded 186 QA pairs from 18 conferences for company PCG.
# Loaded 305 QA pairs from 20 conferences for company ADP.
# Loaded 219 QA pairs from 15 conferences for company SBAC.
# Loaded 210 QA pairs from 24 conferences for company NVDA.
# Loaded 280 QA pairs from 20 conferences for company KR.
# Loaded 236 QA pairs from 22 conferences for company ABT.
# Loaded 247 QA pairs from 21 conferences for company EQIX.
# Loaded 366 QA pairs from 14 conferences for company CTAS.
# Loaded 134 QA pairs from 15 conferences for company GILD.
# Loaded 152 QA pairs from 17 conferences for company CSGP.
# Loaded 207 QA pairs from 15 conferences for company GIS.
# Loaded 187 QA pairs from 20 conferences for company CTVA.
# Loaded 390 QA pairs from 22 conferences for company TRGP.
# Loaded 331 QA pairs from 23 conferences for company CI.
# Loaded 322 QA pairs from 21 conferences for company QCOM.
# Loaded 116 QA pairs from 19 conferences for company BLK.
# Loaded 231 QA pairs from 19 conferences for company KO.
# Loaded 151 QA pairs from 20 conferences for company EXC.
# Loaded 260 QA pairs from 21 conferences for company F.
# Loaded 224 QA pairs from 14 conferences for company MLM.
# Loaded 304 QA pairs from 19 conferences for company VMC.
# Loaded 230 QA pairs from 22 conferences for company JNJ.
# Loaded 383 QA pairs from 21 conferences for company GS.
# Loaded 263 QA pairs from 17 conferences for company TT.
# Loaded 176 QA pairs from 15 conferences for company ETR.
# Loaded 135 QA pairs from 14 conferences for company PANW.
# Loaded 290 QA pairs from 22 conferences for company NOW.
# Loaded 127 QA pairs from 8 conferences for company IFF.
# Loaded 248 QA pairs from 24 conferences for company GOOG.
# Loaded 180 QA pairs from 16 conferences for company EA.
# Loaded 266 QA pairs from 23 conferences for company AXP.
# Loaded 227 QA pairs from 21 conferences for company DIS.
# Loaded 133 QA pairs from 20 conferences for company FOXA.
# Loaded 405 QA pairs from 20 conferences for company ETN.
# Loaded 68 QA pairs from 7 conferences for company FCX.
# Loaded 272 QA pairs from 19 conferences for company LLY.
# Loaded 373 QA pairs from 20 conferences for company KMB.
# Loaded 294 QA pairs from 20 conferences for company EOG.
# Loaded 302 QA pairs from 23 conferences for company CBRE.
# Loaded 136 QA pairs from 21 conferences for company MNST.
# Loaded 241 QA pairs from 22 conferences for company ISRG.
# Loaded 220 QA pairs from 19 conferences for company SYY.
# Loaded 244 QA pairs from 15 conferences for company ALB.
# Loaded 106 QA pairs from 15 conferences for company D.
# Loaded 266 QA pairs from 14 conferences for company AVB.
# Loaded 150 QA pairs from 15 conferences for company OMC.
# Loaded 443 QA pairs from 22 conferences for company VLO.
# Loaded 295 QA pairs from 17 conferences for company EMN.
# Loaded 137 QA pairs from 12 conferences for company AMT.
# Loaded 197 QA pairs from 17 conferences for company STZ.
# Loaded 131 QA pairs from 22 conferences for company NWS.
# Loaded 209 QA pairs from 15 conferences for company OXY.
# Loaded 138 QA pairs from 17 conferences for company IRM.
# Loaded 63 QA pairs from 4 conferences for company AEP.
# Loaded 118 QA pairs from 15 conferences for company CRM.
# Loaded 195 QA pairs from 14 conferences for company CTRA.
# Loaded 311 QA pairs from 20 conferences for company WMT.
# Loaded 204 QA pairs from 15 conferences for company DOW.
# Loaded 249 QA pairs from 17 conferences for company VZ.
# Loaded 290 QA pairs from 23 conferences for company HON.
# Loaded 168 QA pairs from 13 conferences for company CB.
# Loaded 204 QA pairs from 17 conferences for company EQT.
# Loaded 497 QA pairs from 24 conferences for company AMD.
# Loaded 439 QA pairs from 17 conferences for company EXR.
# Loaded 220 QA pairs from 19 conferences for company BA.
# Loaded 114 QA pairs from 11 conferences for company VRTX.
# Loaded 114 QA pairs from 13 conferences for company NEE.
# Loaded 197 QA pairs from 15 conferences for company SLB.
# Loaded 283 QA pairs from 23 conferences for company TJX.
# Loaded 307 QA pairs from 22 conferences for company XOM.
# Loaded 211 QA pairs from 18 conferences for company DUK.
# Loaded 97 QA pairs from 10 conferences for company DE.
# Loaded 242 QA pairs from 17 conferences for company CAT.
# Loaded 251 QA pairs from 15 conferences for company O.
# Loaded 387 QA pairs from 22 conferences for company COST.
# Loaded 372 QA pairs from 21 conferences for company PGR.
# Loaded 105 QA pairs from 8 conferences for company ELV.
# Loaded 293 QA pairs from 13 conferences for company ESS.
# Loaded 194 QA pairs from 15 conferences for company BMY.
# Loaded 248 QA pairs from 21 conferences for company XEL.
# Loaded 263 QA pairs from 15 conferences for company CF.
# Loaded 184 QA pairs from 12 conferences for company DD.
# Loaded 292 QA pairs from 20 conferences for company COP.
# Loaded 219 QA pairs from 16 conferences for company DVN.
# Loaded 263 QA pairs from 22 conferences for company PM.
# Loaded 278 QA pairs from 15 conferences for company PSA.
# Loaded 157 QA pairs from 16 conferences for company SBUX.
# Loaded 152 QA pairs from 14 conferences for company MOS.
# Loaded 20 QA pairs from 5 conferences for company SCHW.
# Loaded 334 QA pairs from 17 conferences for company UNP.
# Loaded 112 QA pairs from 13 conferences for company PPL.
# Loaded 207 QA pairs from 21 conferences for company T.
# Loaded 277 QA pairs from 19 conferences for company ABBV.
# Loaded 246 QA pairs from 16 conferences for company UPS.
# Loaded 240 QA pairs from 17 conferences for company ORLY.
# Loaded 124 QA pairs from 14 conferences for company MCK.
# Loaded 319 QA pairs from 20 conferences for company WFC.
# Loaded 132 QA pairs from 10 conferences for company LOW.
# Loaded 346 QA pairs from 18 conferences for company CCI.
# Loaded 208 QA pairs from 17 conferences for company MDLZ.
# Loaded 124 QA pairs from 15 conferences for company VST.
# Loaded 345 QA pairs from 23 conferences for company RTX.
# Loaded 331 QA pairs from 24 conferences for company TSLA.
# Loaded 210 QA pairs from 14 conferences for company HAL.
# Loaded 184 QA pairs from 15 conferences for company HLT.
# Loaded 199 QA pairs from 13 conferences for company SPG.
# Loaded 370 QA pairs from 22 conferences for company BAC.
# Loaded 416 QA pairs from 23 conferences for company SPGI.
# Loaded 250 QA pairs from 15 conferences for company HD.
# Loaded 102 QA pairs from 11 conferences for company TGT.
# Loaded 175 QA pairs from 13 conferences for company DLR.
# Loaded 134 QA pairs from 14 conferences for company NUE.
# Loaded 249 QA pairs from 15 conferences for company MMM.
# Loaded 298 QA pairs from 19 conferences for company LIN.
# Loaded 242 QA pairs from 22 conferences for company PEG.
# Loaded 218 QA pairs from 22 conferences for company MRK.
# Loaded 171 QA pairs from 16 conferences for company GE.
# Loaded 156 QA pairs from 21 conferences for company PYPL.
# Loaded 251 QA pairs from 22 conferences for company BSX.
# Loaded 380 QA pairs from 22 conferences for company PLD.
# Loaded 194 QA pairs from 16 conferences for company PEP.
# Loaded 184 QA pairs from 14 conferences for company SRE.
# Loaded 173 QA pairs from 13 conferences for company MPC.
# Loaded 373 QA pairs from 23 conferences for company CVX.
# Loaded 185 QA pairs from 23 conferences for company MSFT.
# Loaded 101 QA pairs from 14 conferences for company NKE.
# Loaded 150 QA pairs from 12 conferences for company TMO.
# Loaded 238 QA pairs from 19 conferences for company MS.
# Loaded 118 QA pairs from 9 conferences for company TMUS.
# Loaded 187 QA pairs from 9 conferences for company EQR.
# Loaded 228 QA pairs from 17 conferences for company HES.
# Loaded 255 QA pairs from 21 conferences for company AVGO.
# Loaded 270 QA pairs from 23 conferences for company META.
# Loaded 331 QA pairs from 23 conferences for company CHTR.
# Loaded 189 QA pairs from 14 conferences for company VICI.
# Loaded 256 QA pairs from 23 conferences for company LMT.
# Loaded 189 QA pairs from 15 conferences for company STLD.
# Loaded 293 QA pairs from 23 conferences for company UBER.
# Loaded 28 QA pairs from 5 conferences for company IPG.
# Loaded 166 QA pairs from 13 conferences for company EMR.
# Loaded 159 QA pairs from 11 conferences for company AZO.
# Loaded 254 QA pairs from 20 conferences for company UNH.
# Loaded 109 QA pairs from 10 conferences for company LYV.
# Loaded 143 QA pairs from 11 conferences for company EIX.
# Loaded 288 QA pairs from 19 conferences for company MO.
# Loaded 153 QA pairs from 15 conferences for company PARA.
# Loaded 331 QA pairs from 15 conferences for company MAR.
# Loaded 183 QA pairs from 13 conferences for company TXN.
# Loaded 328 QA pairs from 14 conferences for company GM.
# Loaded 399 QA pairs from 17 conferences for company TTWO.
# Loaded 222 QA pairs from 18 conferences for company ADBE.
# Loaded 433 QA pairs from 21 conferences for company GD.
# Loaded 27 QA pairs from 2 conferences for company GEV.
# Loaded 477 QA pairs from 23 conferences for company INTU.
# Loaded 198 QA pairs from 21 conferences for company ICE.
# Loaded 345 QA pairs from 14 conferences for company DTE.
# Loaded 410 QA pairs from 21 conferences for company PH.
# Loaded 55 QA pairs from 4 conferences for company BX.
# Loaded 275 QA pairs from 22 conferences for company CL.
# Loaded 511 QA pairs from 21 conferences for company C.
# Loaded 130 QA pairs from 10 conferences for company LYB.

# %%
evidence = PopulationEvidenceAnalyzer(cfg)
df_pop = evidence.compute_population_evidence(df_all)

plotter = AggregatedEffectPlotter(cfg)
plotter.forest_plot_aggregated_combined(df_all)
plotter.grouped_violin_by_emotion(df_all)

# %% [markdown]
# ## Conclusions: emotions vs. response behavior (Yes vs. Evasive)
#
# **Definition reminder**
# Effect size is Hedges g = Yes − Evasive
# - **g > 0** → emotion stronger when the question *is answered*
# - **g < 0** → emotion stronger when the question *is evaded*
# - There is population-level evidence if CI doestnt cross x=0.
#
# The conclusions below combine:
# - **Violin plots** → distribution and heterogeneity across companies
# - **Aggregated forest plot** → population-level evidence (mean + 95% CI)
#
# ---
#
# ### Sadness
# - **Direction**: g < 0 (audio & text)
# - **Evidence**: population-level evidence in both modalities
# - **Interpretation**:
#   Evaded questions systematically show more sadness, both in how things are said (audio) and what is said (text).
#   This is the most robust emotional signal in the analysis.
#
# ---
#
# ### Anger
# - **Direction**: g < 0 in text, ~0 in audio
# - **Evidence**: population-level evidence only in text
# - **Interpretation**:
#   Evaded answers tend to contain more anger in the textual content, but this is not clearly reflected in vocal tone.
#   This points to multimodal dissonance, not a strong global anger effect.
#
# ---
#
# ### Happy
# - **Direction**: g > 0 in audio, ~0 in text
# - **Evidence**: population-level evidence only in audio
# - **Interpretation**:
#   When questions are answered, speakers sound slightly more positive, but this positivity is not clearly expressed in the text.
#
# ---
#
# ### Neutral
# - **Direction**: g > 0 in text, ~0 in audio
# - **Evidence**: clear population-level evidence in text
# - **Interpretation**:
#   Direct answers are **systematically more neutral in wording**, while evasive answers deviate from neutral language.
#   This effect is semantic rather than prosodic.
#
# ---
#
# ### Fear — **secondary, text-only effect**
# - **Direction**: g < 0 in text, ~0 in audio
# - **Evidence**: population-level evidence only in text
# - **Interpretation**:
#   Evaded answers show slightly more fear in text, but the effect is not mirrored in audio.
#
# ---
#
# ### Disgust
# - **Direction**: g < 0 in text, ~0 in audio
# - **Evidence**: population-level evidence only in text
# - **Interpretation**:
#    Evaded answers show slightly more fear in text.
#
# ---
#
# ### Surprise
# - **Direction**: g > 0 in text, g < 0 in audio
# - **Evidence**: limited and not robust
# - **Interpretation**:
#   Surprise does not play a central role in distinguishing response behavior.
